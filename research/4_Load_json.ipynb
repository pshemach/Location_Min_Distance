# %%
import json

# %%
file_path = '../data/osrm_distance_matrix.json'

# %%
# Open a JSON file and load its contents into a Python dictionary
with open(file_path, "r") as file:
    data = json.load(file)

# %%
data['distance_matrix']
# Out:
# [[0.0,
#   53.5289,
#   117.14569999999999,
#   76.1327,
#   102.9948,
#   132.69879999999998,
#   103.9614,
#   70.8661,
#   62.8791,
#   39.612,
#   131.9956,
#   111.311,
#   116.6007,
#   98.50760000000001,
#   113.18939999999999,
#   71.1478,
#   131.9508,
#   31.3265,
#   157.3869,
#   45.4115,
#   73.6527,
#   87.7496,
#   116.8822,
#   123.2267,
#   103.262,
#   73.9666,
#   72.0033,
#   103.8198,
#   145.03320000000002],
#  [53.5289,
#   0.0,
#   109.70739999999999,
#   79.4945,
#   157.0729,
#   169.4899,
#   140.767,
#   95.8095,
#   96.4586,
#   73.19160000000001,
#   163.2395,
#   144.8905,
#   123.1707,
#   132.0871,
#   144.4334,
#   96.0912,
#   156.1096,
#   25.077900000000003,
#   149.9486,
#   37.9732,
#   87.935,
#   125.6694,
#   150.4617,
#   154.47070000000002,
#   136.8415,
#   107.54610000000001,
#   96.94669999999999,
#   135.9846,
#   163.02329999999998],
#  [117.14569999999999,
#   109.70739999999999,
#   0.0,
#   57.749,
#   187.2679,
# ...

# %%
origin = "Medawachchiya"
destination =  "Nochchiyagama"

# %%
route_data = data['route_data']

# %%
for route in route_data:
    if route['origin'] == origin and route['destination'] == destination:
        print(route)
        break
    elif route["origin"] == destination and route["destination"] == origin:
        print(route)
        break
# Out:
# {'origin': 'Nochchiyagama', 'destination': 'Medawachchiya', 'distance': 53.5289, 'path_cords': [[80.210328, 8.263934], [80.210446, 8.26367], [80.210835, 8.26385], [80.212091, 8.264438], [80.215307, 8.265912], [80.216566, 8.266473], [80.221407, 8.268629], [80.221558, 8.268697], [80.223288, 8.269467], [80.223468, 8.269547], [80.224286, 8.269912], [80.226199, 8.270763], [80.227337, 8.27127], [80.227729, 8.271445], [80.229255, 8.272022], [80.229379, 8.272069], [80.230915, 8.27265], [80.231415, 8.272839], [80.231651, 8.272929], [80.233865, 8.273768], [80.235082, 8.27423], [80.235266, 8.274296], [80.238244, 8.275423], [80.240149, 8.276143], [80.242369, 8.277001], [80.245102, 8.278057], [80.246139, 8.278457], [80.248149, 8.279233], [80.248899, 8.2795], [80.250437, 8.280046], [80.250741, 8.280116], [80.252186, 8.280394], [80.252697, 8.280489], [80.255284, 8.281525], [80.256851, 8.282153], [80.258338, 8.282718], [80.258462, 8.282765], [80.260158, 8.282791], [80.262399, 8.283674], [80.264157, 
# ...

# %%
def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)


def find_route(route_data, origin, destination):
    # data = load_json(file_path)
    # route_data = data['route_data']
    for route in route_data:
        if route['origin'] == origin and route['destination'] == destination:
            return route
        elif route["origin"] == destination and route["destination"] == origin:
            return route
    return None

# %%
data = load_json(file_path=file_path)

# %%
distance_matrix = data['distance_matrix']

# %%
distance_matrix
# Out:
# [[0.0,
#   53.5289,
#   117.14569999999999,
#   76.1327,
#   102.9948,
#   132.69879999999998,
#   103.9614,
#   70.8661,
#   62.8791,
#   39.612,
#   131.9956,
#   111.311,
#   116.6007,
#   98.50760000000001,
#   113.18939999999999,
#   71.1478,
#   131.9508,
#   31.3265,
#   157.3869,
#   45.4115,
#   73.6527,
#   87.7496,
#   116.8822,
#   123.2267,
#   103.262,
#   73.9666,
#   72.0033,
#   103.8198,
#   145.03320000000002],
#  [53.5289,
#   0.0,
#   109.70739999999999,
#   79.4945,
#   157.0729,
#   169.4899,
#   140.767,
#   95.8095,
#   96.4586,
#   73.19160000000001,
#   163.2395,
#   144.8905,
#   123.1707,
#   132.0871,
#   144.4334,
#   96.0912,
#   156.1096,
#   25.077900000000003,
#   149.9486,
#   37.9732,
#   87.935,
#   125.6694,
#   150.4617,
#   154.47070000000002,
#   136.8415,
#   107.54610000000001,
#   96.94669999999999,
#   135.9846,
#   163.02329999999998],
#  [117.14569999999999,
#   109.70739999999999,
#   0.0,
#   57.749,
#   187.2679,
# ...
